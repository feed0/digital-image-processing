# %% [markdown]
# # Face Detection with Haar Cascades
#
# **Note: This is face *detection* NOT face *recognition*. We are only detecting if a face is in an image, not who the face actually is. That requires deep learning which we'll go over later!**

# %%
import numpy as np
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Images

# %%
nadia = cv2.imread('Nadia_Murad.jpg',0)
denis = cv2.imread('Denis_Mukwege.jpg',0)
solvay = cv2.imread('solvay_conference.jpg',0)

# %%
plt.imshow(nadia,cmap='gray')

# %%
plt.imshow(denis,cmap='gray')

# %%
plt.imshow(solvay,cmap='gray')

# %% [markdown]
# ## Cascade Files
#
# OpenCV comes with these pre-trained cascade files, we've relocated the .xml files for you in our own DATA folder.

# %% [markdown]
# ## Face Detection

# %%
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_default.xml')

# %%
def detect_face(img):
    
  
    face_img = img.copy()
  
    face_rects = face_cascade.detectMultiScale(face_img) 
    
    for (x,y,w,h) in face_rects: 
        cv2.rectangle(face_img, (x,y), (x+w,y+h), (255,255,255), 10) 
        
    return face_img

# %%
result = detect_face(denis)

# %%
plt.imshow(result,cmap='gray')

# %%
result = detect_face(nadia)
plt.imshow(result,cmap='gray')

# %%
# Gets errors!
result = detect_face(solvay)
plt.imshow(result,cmap='gray')

# %%
def adj_detect_face(img, scaleFactor=1.2, minNeighbors=5):
    
    face_img = img.copy()

    face_rects = face_cascade.detectMultiScale(face_img, scaleFactor=scaleFactor, minNeighbors=minNeighbors)

    for (x,y,w,h) in face_rects: 
        cv2.rectangle(face_img, (x,y), (x+w,y+h), (255,255,255), 10) 
        
    return face_img

# %%
# Doesn't detect the side face.
result = adj_detect_face(solvay)
plt.imshow(result,cmap='gray')

# %%
result = adj_detect_face(solvay, scaleFactor=2.4)
plt.imshow(result, cmap='gray')

# %% [markdown]
# ## Eye Cascade File

# %%
eye_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_eye.xml')

# %%
def detect_eyes(img):
    
    face_img = img.copy()
  
    eyes = eye_cascade.detectMultiScale(face_img) 
    
    
    for (x,y,w,h) in eyes: 
        cv2.rectangle(face_img, (x,y), (x+w,y+h), (255,255,255), 10) 
        
    return face_img

# %%
result = detect_eyes(nadia)
plt.imshow(result,cmap='gray')

# %%
eyes = eye_cascade.detectMultiScale(denis)

# %%
# White around the pupils is not distinct enough to detect Denis' eyes here!
result = detect_eyes(denis)
plt.imshow(result,cmap='gray')

# %% [markdown]
# Take a look at the other cascade files, you'll be using them in your upcoming project exercise!

# %% [markdown]
# ## Conjunction with Video

# %%
cap = cv2.VideoCapture(0) 

while True: 
    
    ret, frame = cap.read(0) 
     
    frame = detect_face(frame)
 
    cv2.imshow('Video Face Detection', frame) 
 
    c = cv2.waitKey(1) 
    if c == 27: 
        break 
        
cap.release() 
cv2.destroyAllWindows()
# Out:
# [ WARN:0@6.392] global cap_gstreamer.cpp:1173 isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# OpenCV: not authorized to capture video (status 0), requesting...
# OpenCV: camera failed to properly initialize!
# [ WARN:0@6.530] global cap.cpp:323 open VIDEOIO(OBSENSOR): raised unknown C++ exception!
# [10/30 18:56:41.755666][info][128300][Context.cpp:69] Context created with config: default config!
# [10/30 18:56:41.755694][info][128300][Context.cpp:74] Context work_dir=/Users/fosorio/dev/digital-image-processing/2025-10-30 DETECCAO DE IMAGENS-20251030
# [10/30 18:56:41.755695][info][128300][Context.cpp:77] 	- SDK version: 1.9.4
# [10/30 18:56:41.755696][info][128300][Context.cpp:78] 	- SDK stage version: main
# [10/30 18:56:41.755698][info][128300][Context.cpp:82] get config EnumerateNetDevice:false
# [10/30 18:56:41.755699][info][128300][MacPal.cpp:36] createObPal: create MacPal!
# [10/30 18:56:41.756048][info][128300][MacPal.cpp:104] Create PollingDeviceWatcher!
# [10/30 18:56:41.756057][info][128300][DeviceManager.cpp:15] Current found device(s): (0)
# [10/30 18:56:41.756059][info][128300][Pipeline.cpp:15] Try to create pipeline with default device.
# [10/30 18:56:41.756061][warning][128300][ObException.cpp:5] No device found, fail to create pipeline!
# [10/30 18:56:41.756284][info][128300][Context.cpp:90] Context destroyed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 7
#       3 while True:
#       5     ret, frame = cap.read(0)
# ----> 7     frame = detect_face(frame)
#       9     cv2.imshow('Video Face Detection', frame)
#      11     c = cv2.waitKey(1)
#
# Cell In[7], line 4, in detect_face(img)
#       1 def detect_face(img):
# ----> 4     face_img = img.copy()
#       6     face_rects = face_cascade.detectMultiScale(face_img)
#       8     for (x,y,w,h) in face_rects:
#
# AttributeError: 'NoneType' object has no attribute 'copy'
