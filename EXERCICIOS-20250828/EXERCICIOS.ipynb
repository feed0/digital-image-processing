# %% [markdown]
# # EXERCICIOS
#
# ## Complete the Tasks in bold below. Keep in mind, you may need to run some of these tasks as Python scripts.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

RED_COLOR = (255, 0, 0)
GREEN_COLOR = (0, 255, 0)
BLUE_COLOR = (0, 0, 255)

# %% [markdown]
# ----------
# #### TASK: Open the *dog_backpack.jpg* image from the DATA folder and display it in the notebook. Make sure to correct for the RGB order.

# %%
img = cv2.imread('dog_backpack.jpg')

# %%
plt.imshow(img)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# #### TASK: Print the matrix of pixels out. Then, you should print the dimension of this matrix. Play around with the colours and size.

# %%
img
# Out:
# array([[[249, 248, 250],
#         [249, 248, 250],
#         [249, 248, 250],
#         ...,
#         [249, 248, 250],
#         [249, 248, 250],
#         [249, 248, 250]],
#
#        [[249, 248, 250],
#         [249, 248, 250],
#         [249, 248, 250],
#         ...,
#         [249, 248, 250],
#         [249, 248, 250],
#         [249, 248, 250]],
#
#        [[249, 248, 250],
#         [249, 248, 250],
#         [249, 248, 250],
#         ...,
#         [249, 248, 250],
#         [249, 248, 250],
#         [249, 248, 250]],
#
#        ...,
#
#        [[ 39,  40,  50],
#         [ 39,  39,  51],
#         [ 38,  38,  52],
#         ...,
#         [ 86,  80,  73],
#         [ 81,  77,  72],
#         [ 79,  75,  70]],
#
#        [[ 40,  41,  51],
#         [ 40,  40,  52],
#         [ 38,  38,  52],
#         ...,
#         [ 88,  82,  75],
#         [ 84,  78,  73],
#         [ 79,  75,  70]],
#
#        [[ 40,  42,  52],
#         [ 38,  40,  51],
#         [ 39,  39,  53],
#         ...,
#         [ 89,  83,  78],
#         [ 84,  78,  71],
#         [ 78,  75,  67]]], shape=(1401, 934, 3), dtype=uint8)

# %%
print(img.shape, img_rgb.shape)
# Out:
# (1401, 934, 3) (1401, 934, 3)

# %% [markdown]
# #### TASK: Flip the image upside down and display it in the notebook.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
upsidedown_img = cv2.flip(img_rgb, 0)
plt.imshow(upsidedown_img)

# %% [markdown]
# #### TASK: Draw an empty RED rectangle around the dogs face and display the image in the notebook.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
img_rgb_rectangle = img_rgb.copy()
cv2.rectangle(
    img_rgb_rectangle,
    pt1 = (200, 350),
    pt2 = (620, 760),
    color = (255, 0, 0),
    thickness = 4)

plt.imshow(img_rgb_rectangle)

# %% [markdown]
# #### TASK: Draw a BLUE TRIANGLE in the middle of the image. The size and angle is up to you, but it should be a triangle (three sides) in any orientation.

# %%
img.shape
# Out:
# (1401, 934, 3)

# %%
height, width = img.shape[0], img.shape[1]
center_x, center_y = width // 2, height // 2

radius = 250

vertices = np.array([
    [center_x         , center_y - radius],
    [center_x - radius, center_y + radius], 
    [center_x + radius, center_y + radius]
], np.int32)

pts = vertices.reshape((-1, 1, 2))

img_rgb_triangle = img_rgb.copy()

cv2.polylines(
    img_rgb_triangle, 
    [pts], 
    isClosed=True, 
    color=BLUE_COLOR, 
    thickness=5)

cv2.circle(
    img_rgb_triangle,
    center = (center_x, center_y),
    radius = 10,
    color = RED_COLOR,
    thickness = -1)

plt.imshow(img_rgb_triangle)

# %% [markdown]
# ### BONUS TASK. Can you figure our how to fill in this triangle? It requires a different function that we didn't show in the lecture! See if you can use google search to find it.
#
# [CLICK ME FOR A DIRECT LINK TO THE HINT](https://docs.opencv.org/3.0-beta/modules/imgproc/doc/drawing_functions.html#fillpoly)

# %% [markdown]
# #### TASK: (NOTE: YOU WILL NEED TO RUN THIS AS A SCRIPT). Create a script that opens the picture and allows you to draw empty red circles whever you click the RIGHT MOUSE BUTTON DOWN.
